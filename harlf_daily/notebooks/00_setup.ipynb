# %% [markdown]
# # Setup & Environment Check
# This notebook verifies that your environment is correctly set up.

# %%
# Check Python version
import sys
print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")
# Out:
# Python version: 3.12.11 | packaged by Anaconda, Inc. | (main, Jun  5 2025, 08:03:38) [Clang 14.0.6 ]
# Python executable: /Users/nataliamarko/miniconda3/envs/demand_forecast_env/bin/python

# %%
# Check PyTorch
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.7.1
# CUDA available: False

# %%
# Check stable-baselines3
import stable_baselines3
print(f"Stable-Baselines3 version: {stable_baselines3.__version__}")
# Out:
# Stable-Baselines3 version: 2.7.0
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
# Test harlf package imports
from harlf import config
print(f"\n✓ Config imported successfully")
print(f"Project root: {config.PROJECT_ROOT}")
print(f"Tickers: {config.TICKERS}")
# Out:
# ✓ Config imported successfully
# Project root: /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/harlf_daily
# Tickers: ['NVDA', 'MU', 'AAPL', 'AMD', 'ASML', 'MSFT', 'GOOG']

# %%
# Test module imports
from harlf.data_pipeline.pipeline import run_full_pipeline
from harlf.envs.portfolio_env import PortfolioEnv
from harlf.agents.dirichlet_policy import SoftmaxActorCriticPolicy
from harlf.training.callbacks import BestModelCallback

print("✓ All imports successful!")
# Out:
# ✓ All imports successful!

# %%
# Verify data directories
print("\nData directories:")
print(f"  Raw data: {config.RAW_DATA_DIR}")
print(f"  Processed data: {config.PROCESSED_DATA_DIR}")
print(f"  Walk-forward: {config.WALK_FORWARD_DIR}")
print(f"  Metadata: {config.METADATA_DIR}")
# Out:
# Data directories:
#   Raw data: /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/harlf_daily/data/raw
#   Processed data: /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/harlf_daily/data/processed
#   Walk-forward: /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/harlf_daily/data/walk_forward
#   Metadata: /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/harlf_daily/data/metadata

# %%
# Check FRED API key (if using macro features)
if hasattr(config, 'FRED_API_KEY'):
    if config.FRED_API_KEY and config.FRED_API_KEY != 'your_fred_api_key_here':
        print(f"✓ FRED API key configured: {config.FRED_API_KEY[:10]}...")
    else:
        print("⚠️  FRED API key not configured. Set FRED_API_KEY in .env file.")
        print("   Get your key at: https://fred.stlouisfed.org/docs/api/api_key.html")
# Out:
# ⚠️  FRED API key not configured. Set FRED_API_KEY in .env file.
#    Get your key at: https://fred.stlouisfed.org/docs/api/api_key.html

# %% [markdown]
# ## Summary
#
# If all cells above ran successfully, your environment is ready!
#
# Next steps:
# 1. Run `01_data_exploration.ipynb` to explore the data
# 2. Run `02_train_base_agents.ipynb` to train your first agent

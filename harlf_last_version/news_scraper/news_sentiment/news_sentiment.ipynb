# %%
from alternative_news_scraper import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# %%
scraper = AlternativeNewsScraper()

# Test with current news
print("\n=== Testing Current News Analysis ===")
test_tickers = ["NVDA", "MSFT", "GOOG"]

current_results = []
for ticker in current_tickers:
    result = scraper.analyze_ticker_current_news(ticker)
    current_results.append(result)
    print(f"{ticker}: {result['article_count']} articles, sentiment: {result['sentiment_score']:.3f}")


all_tickers = [
    "AEM","AI","AMD","APP","ARBE","ASML","GOOG","IONQ","MRVL",
    "MSFT","MU","NVDA","PLTR","QBTS","RDDT","RGTI","SMR","VERU","QQQ"
]

# Create pivot table
pivot_df = df.pivot_table(
    index=['year', 'month'], 
    columns='ticker', 
    values='sentiment_score'
)
pivot_df.to_csv('sentiment_matrix_2020_2024.csv')

# %% [markdown]
# # LSTM Reinforcement Learning Pipeline (Expanded & Lean)
#
# This notebook runs the complete pipeline for the LSTM agent using the **Expanded Feature Set** (175 features) and **Lean Feature Selection**.
#
# **Steps:**
# 1. Feature Analysis
# 2. Training (Walk-Forward Validation)
# 3. Performance Visualization
# 4. Backtesting

# %% [markdown]
# ## Step 1: Feature Analysis
# Analyze feature importance to verify the expanded feature set.

# %%
# %run ../mlp/analyze_features.py --expanded
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# ...
# ANALYZING FEATURE IMPORTANCE (EXPANDED SET)
# ...
# Loading test set from /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/data/expanded/test_set_NEVER_TOUCH.csv
#
# Creating expanded features...
# Creating EXPANDED feature set with rich technical indicators...
# Expanded features shape: (50, 140)
# Features shape: (50, 140)
#
# No suitable model found (or forced training). Training quick model...
# ...
# TRAINING QUICK MODEL FOR FEATURE IMPORTANCE ANALYSIS
# ...

# %% [markdown]
# ## Step 2: Train Model
# Train the LSTM agent using Walk-Forward Validation (3 Folds).

# %%
# %run train_lstm.py --expanded --lean
# Out:
# Output()
# ...
# STARTING LSTM TRAINING (EXPANDED-LEAN MODE)
# ...
#
# Loading RAW price data...
#    Mode: EXPANDED-LEAN
#    Train data: /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/data/expanded/raw_data_train.csv
#    Test data: /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/data/expanded/test_set_NEVER_TOUCH.csv
#
# Total samples: 495
# Fold size: 123
#
# ...
# FOLD 1/3
# ...
#
# Creating features for fold 1...
#    Using EXPANDED feature set (~175 features)
# Creating EXPANDED feature set with rich technical indicators...
# Expanded features shape: (229, 140)
# Selected 95 features out of 140
# Selected 98 features (including 7 return columns)
# Train features shape: (71, 98)
# Val features shape: (102, 98)
#
# Initializing RecurrentPPO (EXPANDED-LEAN) for fold 1...
#
# 🚀 Training fold 1...
# Eval num_timesteps=2000, episode_reward=7.69 +/- 0.00
# Episode length: 26.00 +/- 0.00
# New best mean reward!
# ...

# %% [markdown]
# ## Step 3: Learning Curves & Stability
# Visualize training progress, validation performance, and stability metrics.

# %%
# %run plot_learning_curves.py --expanded --lean
# Out:
# ...
# GENERATING LEARNING CURVES (EXPANDED-LEAN)
# ...
# Using logs directory: /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/lstm/logs_expanded_lean
#
# Processing Fold 1...
# Loaded 5560 training episodes for Fold 1
# Loaded 50 validation evaluations for Fold 1
#
# Processing Fold 2...
# Loaded 2042 training episodes for Fold 2
# Loaded 50 validation evaluations for Fold 2
#
# Processing Fold 3...
# Loaded 1267 training episodes for Fold 3
# Loaded 50 validation evaluations for Fold 3
#
# ✅ Learning curves saved to /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/outputs/lstm_learning_curves_expanded_lean.png
#
# Generating fold comparison plot...
# ✅ Fold comparison saved to /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/outputs/lstm_fold_comparison.png
#
# Analyzing training stability...
#
# ...
# TRAINING STABILITY ANALYSIS (Reward Units)
# ...

# %% [markdown]
# ## Step 4: Backtesting
# Test the final model on the held-out test set.

# %%
# %run backtest.py --expanded --lean
# Out:
# ...
# BACKTESTING ON HELD-OUT TEST SET (EXPANDED-LEAN MODE)
# ...
#
# Loading test set from /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/data/expanded/test_set_NEVER_TOUCH.csv
# Test period: 2023-06-28 00:00:00 to 2025-10-29 00:00:00
# Test duration: 123 weeks
#
# Creating features for test set...
#    Using EXPANDED feature set (~175 features)
# Creating EXPANDED feature set with rich technical indicators...
# Expanded features shape: (50, 140)
# Using LEAN feature set
# Selected 95 features out of 140
# Selected 98 features (including 7 return columns)
# Test features shape: (50, 98)
# Found overall best model: /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/lstm/models_expanded_lean/best_overall_model.zip
#
# Loading model from /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/lstm/models_expanded_lean/best_overall_model.zip
#
# Running backtest...
# ...

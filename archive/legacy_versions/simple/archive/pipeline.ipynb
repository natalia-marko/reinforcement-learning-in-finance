# %% [markdown]
# # RL Portfolio Optimization Pipeline (Expanded & Lean)
#
# This notebook runs the complete pipeline for the reinforcement learning agent using the **Expanded Feature Set** (175 features) and **Lean Feature Selection**.
#
# **Steps:**
# 1. Feature Analysis
# 2. Training (Walk-Forward Validation)
# 3. Performance Visualization
# 4. Backtesting

# %%
# %run core/data_loading_preprocessing.py
# Out:
# ...
# DATA ENGINEERING PIPELINE
# ...
#
# ...
# TRAIN/TEST SPLIT (LEAK-FREE)
# ...
# [*********************100%***********************]  7 of 7 completed
# [*********************100%***********************]  5 of 5 completed
# Split date: 2023-06-21 00:00:00
#    Train: 2014-01-01 00:00:00 to 2023-06-21 00:00:00
#    Test:  2023-06-21 00:00:00 to 2025-10-29 00:00:00
#
# Train: 494 weeks, Test: 124 weeks
# Saved: /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/data/raw_data_train.csv
# Saved: /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/data/test_set_NEVER_TOUCH.csv
# No feature selection file found, using all features
#
# Features: 266 columns, 447 samples
#
# Train features: (447, 266)
# Date range: 2014-11-26 00:00:00 to 2023-06-14 00:00:00
# Saved: /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/outputs/train_features.csv

# %% [markdown]
# ## Step 1: Feature Analysis
# Analyze feature importance to verify the expanded feature set.

# %%
# %run core/analyze_features.py
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# ...
# ANALYZING FEATURE IMPORTANCE
# ...
# Loading train set from /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/data/raw_data_train.csv
#
# Creating features...
# Features shape: (447, 224)
#
# No suitable model found (or forced training). Training quick model...
# ...
# TRAINING QUICK MODEL FOR FEATURE IMPORTANCE ANALYSIS
# ...
#
# Creating environment...
#
# Training QUICK MLP model (10k timesteps for speed)...
# Output()
# ...

# %% [markdown]
# ## Step 2: Train Model
# Train the agent using Walk-Forward Validation (3 Folds).

# %%
# %run core/train.py
# Out:
# ...
# STARTING TRAINING
# ...
#
# Loading price data...
# Total samples: 494
# Fold size: 123
# Number of folds: 3
#
# ...
# FOLD 1/3
# ...
# Train: 0 to 123 (123 samples)
# Val: 131 to 254 (123 samples)
#
# Creating features...
# Output()
# Train features: (76, 98)
# Val features: (123, 98)
# Warming up normalization statistics...
#
# 📊 Training Schedule:
#    Epochs: 100
#    Total timesteps: 7,600
#    Eval frequency: every 5 epochs
#
# 🚀 Training fold 1...
# Eval num_timesteps=380, episode_reward=22.46 +/- 0.00
# Episode length: 31.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=760, episode_reward=23.28 +/- 0.00
# Episode length: 31.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=1140, episode_reward=23.00 +/- 0.00
# Episode length: 31.00 +/- 0.00
# Eval num_timesteps=1520, episode_reward=23.10 +/- 0.00
# Episode length: 31.00 +/- 0.00
# Eval num_timesteps=1900, episode_reward=24.39 +/- 0.00
# Episode length: 31.00 +/- 0.00
# New best mean reward!
# ...

# %% [markdown]
# ## Step 3: Learning Curves & Stability
# Visualize training progress, validation performance, and stability metrics.

# %%
# %run core/plot.py
# Out:
# ...
# GENERATING LEARNING CURVES
# ...
#
# Processing Fold 1...
# Loaded 430 training episodes for Fold 1
# Loaded 20 validation evaluations for Fold 1
#
# Processing Fold 2...
# Loaded 409 training episodes for Fold 2
# Loaded 20 validation evaluations for Fold 2
#
# Processing Fold 3...
# Loaded 404 training episodes for Fold 3
# Loaded 20 validation evaluations for Fold 3
# ✅ Learning curves saved to /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/outputs/learning_curves.png
#
# Generating fold comparison plot...
# ✅ Fold comparison saved to /Users/nataliamarko/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/outputs/fold_comparison.png
#
# Analyzing training stability...
#
# ...
# TRAINING STABILITY ANALYSIS
# ...
#  fold  train_mean  train_std  train_final  val_best  val_final  val_std  val_episode_std  overfit_gap
#     1        7.08       7.39        16.20 24.690001  24.690001     0.85              0.0        -8.49
# ...

# %% [markdown]
# ## Step 4: Backtesting
# Test the final model on the held-out test set.

# %%
# %run core/plot_allocations.py
# Out:
# ...
# PORTFOLIO ALLOCATION VISUALIZATION
# ...
#
# 📊 Loading test data...
# 🔧 Creating features...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/core/plot_allocations.py:160
#     157         print(f"\n✅ Detailed weights saved to {weights_csv}")
#     159 if __name__ == "__main__":
# --> 160     main()
#
# File ~/Documents/GitHub_Projects/reinforcement_learning_in_finance/simple/core/plot_allocations.py:83, in main()
#      80 test_prices = test_data['prices']
#      82 print("🔧 Creating features...")
# ---> 83 test_features_full = create_features(test_prices, None, lean=False, drop_zero_var=False)
#      84 test_features = get_lean_features(test_features_full)
#      86 # Load model first to check expected observation shape
#
# TypeError: create_features() got an unexpected keyword argument 'lean'

# %% [markdown]
# # setup_and_data_generation

# %%
# !pip install stable-baselines3 shimmy gymnasium pandas numpy matplotlib
import gymnasium as gym
from gymnasium import spaces
import pandas as pd
import numpy as np
import os
import yfinance as yf
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnNoModelImprovement
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.env_checker import check_env
from rl_system import *
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
# --- Configuration ---
WINDOW_SIZE = 60       
RISK_AVERSION = 4.0
TX_COST_BPS = 0.0010   
REBALANCE_THRESHOLD = 0.05 

def load_real_data(tickers=None, benchmark='QQQ', start='2015-01-01', end='2025-10-31'):
    """
    Robust loader for Yahoo Finance data.
    Fixes: Timezones, Missing Values (FFILL), and MultiIndex formatting.
    """
    if tickers is None:
        # Tech heavy portfolio
        tickers = ['NVDA', 'MU', 'AAPL', 'AMD', 'ASML', 'MSFT', 'GOOG']
    
    # Download everything at once
    all_tickers = tickers + [benchmark]
    print(f"Downloading {len(all_tickers)} assets...")
    
    # auto_adjust=True gives us 'Close' adjusted for splits/dividends
    raw_data = yf.download(all_tickers, start=start, end=end, progress=False, auto_adjust=True)
    
    # 1. Handle YFinance MultiIndex (Price Type, Ticker)
    # The columns usually look like ('Close', 'AAPL'). We just want the 'Close' slice.
    if isinstance(raw_data.columns, pd.MultiIndex):
        try:
            # Try grabbing the 'Close' cross-section directly
            df = raw_data['Close'].copy()
        except KeyError:
            # Fallback if yfinance changes format or case
            df = raw_data['close'].copy()
    else:
        df = raw_data.copy()

    # 2. Rename Benchmark to 'SPY' 
    # (The Environment expects a column named 'SPY' for the market regime logic)
    if benchmark in df.columns:
        df = df.rename(columns={benchmark: 'SPY'})
    
    # 3. Data Cleaning (Crucial for RL)
    # Forward Fill first (carry forward yesterday's price to fill holidays)
    df = df.ffill()
    # Then drop any remaining NaNs (usually the first few days if data starts at different times)
    df = df.dropna().round(2)
    
    # 4. Strip Timezone (Make it naive)
    df.index = df.index.tz_localize(None)
    
    # 5. Reorder: Assets first, Benchmark last
    # This ensures the matrix slicing in the Env works as expected
    asset_cols = [t for t in tickers if t in df.columns]
    final_cols = asset_cols + ['SPY']
    
    # Verify we didn't lose the benchmark
    if 'SPY' not in df.columns:
        raise ValueError("Benchmark failed to download or rename!")
        
    return df[final_cols]

# Load and Verify

df_full = load_real_data()
print(f"Data Successfully Loaded: {df_full.shape}")
print(f"Date Range: {df_full.index.min()} to {df_full.index.max()}")
print("Sample:")
df_full.tail()
# Out:
# Downloading 8 assets...
# Data Successfully Loaded: (2724, 8)
# Date Range: 2015-01-02 00:00:00 to 2025-10-30 00:00:00
# Sample:
# Ticker        NVDA      MU    AAPL     AMD     ASML    MSFT    GOOG     SPY
# Date
# 2025-10-24  186.26  219.02  262.57  252.92  1031.27  522.63  260.51  617.10
# 2025-10-27  191.49  220.10  268.55  259.67  1058.10  530.53  269.93  628.09
# 2025-10-28  201.03  221.91  268.74  258.01  1050.62  541.06  268.43  632.92
# 2025-10-29  207.04  226.63  269.44  264.33  1070.84  540.54  275.17  635.77
# 2025-10-30  202.89  224.01  271.14  254.84  1075.45  524.78  281.90  626.05

# %% [markdown]
# # Feature Engineering (The Processor)
#
# Vectorized calculation of the "Golden 4" indicators.

# %%
# Run Pipeline
engineer = FinancialFeatureEngineer()
features, prices, benchmark = engineer.preprocess_data(df_full)


# Split Train (80%) / Test (20%)
split_idx = int(len(df_full) * 0.8)

feat_train, feat_test = features[:split_idx], features[split_idx:]
price_train, price_test = prices[:split_idx], prices[split_idx:]
bench_train, bench_test = benchmark[:split_idx], benchmark[split_idx:]
dates_test = df_full.index[split_idx:]

print(f"Training Shape: {feat_train.shape}")
print(f"Testing Shape: {feat_test.shape}")
# Out:
# Training Shape: (2179, 7, 3)
# Testing Shape: (545, 7, 3)

# %% [markdown]
# The Environment (Logic Core)
#
# The custom Gym environment with Monthly steps and Daily risk awareness.

# %%
# Create directory if it doesn't exist
os.makedirs('./data', exist_ok=True)

# Save full arrays
np.save('./data/features.npy', features)
np.save('./data/prices.npy', prices)
np.save('./data/benchmark.npy', benchmark)

# Save train/test splits
np.save('./data/feat_train.npy', feat_train)
np.save('./data/feat_test.npy', feat_test)
np.save('./data/price_train.npy', price_train)
np.save('./data/price_test.npy', price_test)
np.save('./data/bench_train.npy', bench_train)
np.save('./data/bench_test.npy', bench_test)

# %% [markdown]
# Training (The Brain)
#
# Setup PPO with the EvalCallback to save the best version.

# %%
# 1. Create Environments
train_env = PortfolioRebalanceEnv(price_train, feat_train, bench_train)
# For Eval, we use the same data here just for demo, 
# in reality use a Validation Split (2018-2019)
eval_env = Monitor(PortfolioRebalanceEnv(price_train, feat_train, bench_train)) 

# 2. Callback
eval_callback = EvalCallback(
    eval_env, 
    best_model_save_path='./logs/',
    log_path='./logs/', 
    eval_freq=2000, 
    deterministic=True, 
    render=False
)

# 3. Model (PPO)
model = PPO(
    "MlpPolicy", 
    train_env, 
    verbose=1,
    learning_rate=3e-4,
    gamma=0.99,
    ent_coef=0.02,
    batch_size=64
)

print("Starting Training...")
model.learn(total_timesteps=100_000, callback=eval_callback)
print("Training Complete.")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Starting Training...
# Eval num_timesteps=2000, episode_reward=-535.27 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 106      |
# |    mean_reward     | -535     |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -543     |
# | time/              |          |
# |    fps             | 4941     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Eval num_timesteps=4000, episode_reward=-533.04 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 106          |
# |    mean_reward          | -533         |
# | time/                   |              |
# |    total_timesteps      | 4000         |
# | train/                  |              |
# |    approx_kl            | 0.0090166265 |
# |    clip_fraction        | 0.0729       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.4        |
# |    explained_variance   | 0.00184      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.69e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.02        |
# |    std                  | 1            |
# |    value_loss           | 6.76e+03     |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -541     |
# | time/              |          |
# |    fps             | 3373     |
# |    iterations      | 2        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6000, episode_reward=-531.55 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -532        |
# | time/                   |             |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.010827905 |
# |    clip_fraction        | 0.0977      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.4       |
# |    explained_variance   | 0.000832    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.11e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0233     |
# |    std                  | 1.01        |
# |    value_loss           | 7.09e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -542     |
# | time/              |          |
# |    fps             | 3077     |
# |    iterations      | 3        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6144     |
# ---------------------------------
# Eval num_timesteps=8000, episode_reward=-532.76 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 106        |
# |    mean_reward          | -533       |
# | time/                   |            |
# |    total_timesteps      | 8000       |
# | train/                  |            |
# |    approx_kl            | 0.01101849 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11.5      |
# |    explained_variance   | 0.000246   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.2e+03    |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0262    |
# |    std                  | 1.02       |
# |    value_loss           | 7.03e+03   |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -540     |
# | time/              |          |
# |    fps             | 2953     |
# |    iterations      | 4        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8192     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=-529.30 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -529        |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.012150817 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.5       |
# |    explained_variance   | 0.000123    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.06e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0284     |
# |    std                  | 1.02        |
# |    value_loss           | 6.46e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -540     |
# | time/              |          |
# |    fps             | 2873     |
# |    iterations      | 5        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 10240    |
# ---------------------------------
# Eval num_timesteps=12000, episode_reward=-531.58 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -532        |
# | time/                   |             |
# |    total_timesteps      | 12000       |
# | train/                  |             |
# |    approx_kl            | 0.014248073 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.5       |
# |    explained_variance   | 6.99e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.01e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0323     |
# |    std                  | 1.02        |
# |    value_loss           | 6.44e+03    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -539     |
# | time/              |          |
# |    fps             | 2829     |
# |    iterations      | 6        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 12288    |
# ---------------------------------
# Eval num_timesteps=14000, episode_reward=-532.45 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -532        |
# | time/                   |             |
# |    total_timesteps      | 14000       |
# | train/                  |             |
# |    approx_kl            | 0.013620329 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.6       |
# |    explained_variance   | 4.57e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.89e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0268     |
# |    std                  | 1.03        |
# |    value_loss           | 6.18e+03    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -540     |
# | time/              |          |
# |    fps             | 2802     |
# |    iterations      | 7        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=-534.67 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -535        |
# | time/                   |             |
# |    total_timesteps      | 16000       |
# | train/                  |             |
# |    approx_kl            | 0.015125692 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.6       |
# |    explained_variance   | 3.11e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.87e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0311     |
# |    std                  | 1.04        |
# |    value_loss           | 6.07e+03    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -540     |
# | time/              |          |
# |    fps             | 2781     |
# |    iterations      | 8        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 16384    |
# ---------------------------------
# Eval num_timesteps=18000, episode_reward=-531.31 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -531        |
# | time/                   |             |
# |    total_timesteps      | 18000       |
# | train/                  |             |
# |    approx_kl            | 0.015326378 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.6       |
# |    explained_variance   | 2.15e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.76e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0309     |
# |    std                  | 1.04        |
# |    value_loss           | 5.88e+03    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -541     |
# | time/              |          |
# |    fps             | 2737     |
# |    iterations      | 9        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 18432    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=-528.40 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 106        |
# |    mean_reward          | -528       |
# | time/                   |            |
# |    total_timesteps      | 20000      |
# | train/                  |            |
# |    approx_kl            | 0.01595138 |
# |    clip_fraction        | 0.175      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11.7      |
# |    explained_variance   | 1.62e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.78e+03   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0301    |
# |    std                  | 1.04       |
# |    value_loss           | 5.83e+03   |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -542     |
# | time/              |          |
# |    fps             | 2718     |
# |    iterations      | 10       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 20480    |
# ---------------------------------
# Eval num_timesteps=22000, episode_reward=-524.29 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 106        |
# |    mean_reward          | -524       |
# | time/                   |            |
# |    total_timesteps      | 22000      |
# | train/                  |            |
# |    approx_kl            | 0.01581423 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11.7      |
# |    explained_variance   | 1.23e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.79e+03   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0303    |
# |    std                  | 1.05       |
# |    value_loss           | 5.53e+03   |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -542     |
# | time/              |          |
# |    fps             | 2703     |
# |    iterations      | 11       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 22528    |
# ---------------------------------
# Eval num_timesteps=24000, episode_reward=-521.04 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -521        |
# | time/                   |             |
# |    total_timesteps      | 24000       |
# | train/                  |             |
# |    approx_kl            | 0.017492764 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.7       |
# |    explained_variance   | 9.42e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.82e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.033      |
# |    std                  | 1.05        |
# |    value_loss           | 5.22e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -541     |
# | time/              |          |
# |    fps             | 2696     |
# |    iterations      | 12       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 24576    |
# ---------------------------------
# Eval num_timesteps=26000, episode_reward=-514.74 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -515        |
# | time/                   |             |
# |    total_timesteps      | 26000       |
# | train/                  |             |
# |    approx_kl            | 0.018847518 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.8       |
# |    explained_variance   | 7.27e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.86e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0301     |
# |    std                  | 1.06        |
# |    value_loss           | 5.21e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -538     |
# | time/              |          |
# |    fps             | 2689     |
# |    iterations      | 13       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 26624    |
# ---------------------------------
# Eval num_timesteps=28000, episode_reward=-510.34 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -510        |
# | time/                   |             |
# |    total_timesteps      | 28000       |
# | train/                  |             |
# |    approx_kl            | 0.020214086 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.8       |
# |    explained_variance   | 5.96e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.06e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0372     |
# |    std                  | 1.06        |
# |    value_loss           | 4.76e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -535     |
# | time/              |          |
# |    fps             | 2669     |
# |    iterations      | 14       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 28672    |
# ---------------------------------
# Eval num_timesteps=30000, episode_reward=-505.37 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -505        |
# | time/                   |             |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.018965412 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.8       |
# |    explained_variance   | 4.83e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.13e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0291     |
# |    std                  | 1.07        |
# |    value_loss           | 4.68e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -533     |
# | time/              |          |
# |    fps             | 2663     |
# |    iterations      | 15       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 30720    |
# ---------------------------------
# Eval num_timesteps=32000, episode_reward=-498.94 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -499        |
# | time/                   |             |
# |    total_timesteps      | 32000       |
# | train/                  |             |
# |    approx_kl            | 0.017452387 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.9       |
# |    explained_variance   | 3.87e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0278     |
# |    std                  | 1.07        |
# |    value_loss           | 4.61e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -531     |
# | time/              |          |
# |    fps             | 2656     |
# |    iterations      | 16       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 32768    |
# ---------------------------------
# Eval num_timesteps=34000, episode_reward=-500.76 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 106        |
# |    mean_reward          | -501       |
# | time/                   |            |
# |    total_timesteps      | 34000      |
# | train/                  |            |
# |    approx_kl            | 0.01990389 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11.9      |
# |    explained_variance   | 3.16e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.85e+03   |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0351    |
# |    std                  | 1.08       |
# |    value_loss           | 4.45e+03   |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -528     |
# | time/              |          |
# |    fps             | 2653     |
# |    iterations      | 17       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 34816    |
# ---------------------------------
# Eval num_timesteps=36000, episode_reward=-499.26 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 106        |
# |    mean_reward          | -499       |
# | time/                   |            |
# |    total_timesteps      | 36000      |
# | train/                  |            |
# |    approx_kl            | 0.01970584 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12        |
# |    explained_variance   | 2.68e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.97e+03   |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0323    |
# |    std                  | 1.09       |
# |    value_loss           | 4.23e+03   |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -527     |
# | time/              |          |
# |    fps             | 2654     |
# |    iterations      | 18       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 36864    |
# ---------------------------------
# Eval num_timesteps=38000, episode_reward=-495.19 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -495        |
# | time/                   |             |
# |    total_timesteps      | 38000       |
# | train/                  |             |
# |    approx_kl            | 0.020937357 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.1       |
# |    explained_variance   | 2.09e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.9e+03     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0307     |
# |    std                  | 1.1         |
# |    value_loss           | 4.19e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -526     |
# | time/              |          |
# |    fps             | 2655     |
# |    iterations      | 19       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 38912    |
# ---------------------------------
# Eval num_timesteps=40000, episode_reward=-497.34 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -497        |
# | time/                   |             |
# |    total_timesteps      | 40000       |
# | train/                  |             |
# |    approx_kl            | 0.023548808 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.1       |
# |    explained_variance   | 1.91e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.12e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0351     |
# |    std                  | 1.1         |
# |    value_loss           | 4.04e+03    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -525     |
# | time/              |          |
# |    fps             | 2655     |
# |    iterations      | 20       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 40960    |
# ---------------------------------
# Eval num_timesteps=42000, episode_reward=-493.01 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -493        |
# | time/                   |             |
# |    total_timesteps      | 42000       |
# | train/                  |             |
# |    approx_kl            | 0.025133157 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.1       |
# |    explained_variance   | 1.37e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.82e+03    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0326     |
# |    std                  | 1.1         |
# |    value_loss           | 4.07e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -524     |
# | time/              |          |
# |    fps             | 2652     |
# |    iterations      | 21       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 43008    |
# ---------------------------------
# Eval num_timesteps=44000, episode_reward=-492.46 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -492        |
# | time/                   |             |
# |    total_timesteps      | 44000       |
# | train/                  |             |
# |    approx_kl            | 0.020682637 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.1       |
# |    explained_variance   | 1.25e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.01e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0307     |
# |    std                  | 1.1         |
# |    value_loss           | 4.05e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -524     |
# | time/              |          |
# |    fps             | 2651     |
# |    iterations      | 22       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 45056    |
# ---------------------------------
# Eval num_timesteps=46000, episode_reward=-494.17 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -494        |
# | time/                   |             |
# |    total_timesteps      | 46000       |
# | train/                  |             |
# |    approx_kl            | 0.023922795 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.1       |
# |    explained_variance   | 1.37e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.9e+03     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0291     |
# |    std                  | 1.11        |
# |    value_loss           | 3.96e+03    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -524     |
# | time/              |          |
# |    fps             | 2640     |
# |    iterations      | 23       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 47104    |
# ---------------------------------
# Eval num_timesteps=48000, episode_reward=-492.41 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -492        |
# | time/                   |             |
# |    total_timesteps      | 48000       |
# | train/                  |             |
# |    approx_kl            | 0.025539342 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 1.19e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.72e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0308     |
# |    std                  | 1.11        |
# |    value_loss           | 3.84e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -525     |
# | time/              |          |
# |    fps             | 2639     |
# |    iterations      | 24       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 49152    |
# ---------------------------------
# Eval num_timesteps=50000, episode_reward=-486.01 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -486        |
# | time/                   |             |
# |    total_timesteps      | 50000       |
# | train/                  |             |
# |    approx_kl            | 0.021789156 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 1.37e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.01e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.029      |
# |    std                  | 1.12        |
# |    value_loss           | 3.97e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -525     |
# | time/              |          |
# |    fps             | 2635     |
# |    iterations      | 25       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 51200    |
# ---------------------------------
# Eval num_timesteps=52000, episode_reward=-483.99 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 106        |
# |    mean_reward          | -484       |
# | time/                   |            |
# |    total_timesteps      | 52000      |
# | train/                  |            |
# |    approx_kl            | 0.02227714 |
# |    clip_fraction        | 0.254      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.3      |
# |    explained_variance   | 2.21e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.17e+03   |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0322    |
# |    std                  | 1.12       |
# |    value_loss           | 3.53e+03   |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -523     |
# | time/              |          |
# |    fps             | 2627     |
# |    iterations      | 26       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 53248    |
# ---------------------------------
# Eval num_timesteps=54000, episode_reward=-480.36 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -480        |
# | time/                   |             |
# |    total_timesteps      | 54000       |
# | train/                  |             |
# |    approx_kl            | 0.026047435 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0.408       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+03    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0317     |
# |    std                  | 1.13        |
# |    value_loss           | 2.77e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -521     |
# | time/              |          |
# |    fps             | 2622     |
# |    iterations      | 27       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 55296    |
# ---------------------------------
# Eval num_timesteps=56000, episode_reward=-477.19 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -477        |
# | time/                   |             |
# |    total_timesteps      | 56000       |
# | train/                  |             |
# |    approx_kl            | 0.026250463 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+03    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0307     |
# |    std                  | 1.14        |
# |    value_loss           | 2.79e+03    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -518     |
# | time/              |          |
# |    fps             | 2618     |
# |    iterations      | 28       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 57344    |
# ---------------------------------
# Eval num_timesteps=58000, episode_reward=-481.00 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -481        |
# | time/                   |             |
# |    total_timesteps      | 58000       |
# | train/                  |             |
# |    approx_kl            | 0.030584259 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.448       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.033      |
# |    std                  | 1.15        |
# |    value_loss           | 2.68e+03    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -516     |
# | time/              |          |
# |    fps             | 2610     |
# |    iterations      | 29       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 59392    |
# ---------------------------------
# Eval num_timesteps=60000, episode_reward=-480.32 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -480        |
# | time/                   |             |
# |    total_timesteps      | 60000       |
# | train/                  |             |
# |    approx_kl            | 0.027156688 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.448       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0276     |
# |    std                  | 1.15        |
# |    value_loss           | 2.8e+03     |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -515     |
# | time/              |          |
# |    fps             | 2609     |
# |    iterations      | 30       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 61440    |
# ---------------------------------
# Eval num_timesteps=62000, episode_reward=-481.86 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 106        |
# |    mean_reward          | -482       |
# | time/                   |            |
# |    total_timesteps      | 62000      |
# | train/                  |            |
# |    approx_kl            | 0.04678528 |
# |    clip_fraction        | 0.479      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.5      |
# |    explained_variance   | 0.453      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 827        |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.0104     |
# |    std                  | 1.16       |
# |    value_loss           | 2.27e+03   |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -514     |
# | time/              |          |
# |    fps             | 2611     |
# |    iterations      | 31       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 63488    |
# ---------------------------------
# Eval num_timesteps=64000, episode_reward=-481.87 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -482        |
# | time/                   |             |
# |    total_timesteps      | 64000       |
# | train/                  |             |
# |    approx_kl            | 0.019619152 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 404         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0361     |
# |    std                  | 1.16        |
# |    value_loss           | 1.39e+03    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -514     |
# | time/              |          |
# |    fps             | 2610     |
# |    iterations      | 32       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 65536    |
# ---------------------------------
# Eval num_timesteps=66000, episode_reward=-481.70 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -482        |
# | time/                   |             |
# |    total_timesteps      | 66000       |
# | train/                  |             |
# |    approx_kl            | 0.023134504 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.6       |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 712         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0389     |
# |    std                  | 1.17        |
# |    value_loss           | 1.23e+03    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -516     |
# | time/              |          |
# |    fps             | 2609     |
# |    iterations      | 33       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 67584    |
# ---------------------------------
# Eval num_timesteps=68000, episode_reward=-477.42 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -477        |
# | time/                   |             |
# |    total_timesteps      | 68000       |
# | train/                  |             |
# |    approx_kl            | 0.028393157 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.6       |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 552         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0411     |
# |    std                  | 1.18        |
# |    value_loss           | 1.1e+03     |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -515     |
# | time/              |          |
# |    fps             | 2609     |
# |    iterations      | 34       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 69632    |
# ---------------------------------
# Eval num_timesteps=70000, episode_reward=-478.61 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -479        |
# | time/                   |             |
# |    total_timesteps      | 70000       |
# | train/                  |             |
# |    approx_kl            | 0.026633538 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.7       |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 312         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0373     |
# |    std                  | 1.19        |
# |    value_loss           | 958         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -516     |
# | time/              |          |
# |    fps             | 2605     |
# |    iterations      | 35       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 71680    |
# ---------------------------------
# Eval num_timesteps=72000, episode_reward=-483.13 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -483        |
# | time/                   |             |
# |    total_timesteps      | 72000       |
# | train/                  |             |
# |    approx_kl            | 0.033566542 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.7       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 364         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0409     |
# |    std                  | 1.19        |
# |    value_loss           | 852         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -516     |
# | time/              |          |
# |    fps             | 2603     |
# |    iterations      | 36       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 73728    |
# ---------------------------------
# Eval num_timesteps=74000, episode_reward=-482.30 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -482        |
# | time/                   |             |
# |    total_timesteps      | 74000       |
# | train/                  |             |
# |    approx_kl            | 0.030481745 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 306         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0362     |
# |    std                  | 1.2         |
# |    value_loss           | 834         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -517     |
# | time/              |          |
# |    fps             | 2603     |
# |    iterations      | 37       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 75776    |
# ---------------------------------
# Eval num_timesteps=76000, episode_reward=-480.94 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -481        |
# | time/                   |             |
# |    total_timesteps      | 76000       |
# | train/                  |             |
# |    approx_kl            | 0.028401114 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 376         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0406     |
# |    std                  | 1.21        |
# |    value_loss           | 724         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -517     |
# | time/              |          |
# |    fps             | 2601     |
# |    iterations      | 38       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 77824    |
# ---------------------------------
# Eval num_timesteps=78000, episode_reward=-478.80 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 106       |
# |    mean_reward          | -479      |
# | time/                   |           |
# |    total_timesteps      | 78000     |
# | train/                  |           |
# |    approx_kl            | 0.0309182 |
# |    clip_fraction        | 0.3       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.9     |
# |    explained_variance   | 0.929     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 282       |
# |    n_updates            | 380       |
# |    policy_gradient_loss | -0.0373   |
# |    std                  | 1.21      |
# |    value_loss           | 575       |
# ---------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -517     |
# | time/              |          |
# |    fps             | 2602     |
# |    iterations      | 39       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 79872    |
# ---------------------------------
# Eval num_timesteps=80000, episode_reward=-474.81 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -475        |
# | time/                   |             |
# |    total_timesteps      | 80000       |
# | train/                  |             |
# |    approx_kl            | 0.029956194 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.9       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 210         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0413     |
# |    std                  | 1.22        |
# |    value_loss           | 514         |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -518     |
# | time/              |          |
# |    fps             | 2600     |
# |    iterations      | 40       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 81920    |
# ---------------------------------
# Eval num_timesteps=82000, episode_reward=-467.55 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -468        |
# | time/                   |             |
# |    total_timesteps      | 82000       |
# | train/                  |             |
# |    approx_kl            | 0.032009494 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13         |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 156         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0366     |
# |    std                  | 1.23        |
# |    value_loss           | 452         |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -516     |
# | time/              |          |
# |    fps             | 2596     |
# |    iterations      | 41       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 83968    |
# ---------------------------------
# Eval num_timesteps=84000, episode_reward=-467.93 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -468        |
# | time/                   |             |
# |    total_timesteps      | 84000       |
# | train/                  |             |
# |    approx_kl            | 0.031827353 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13         |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 133         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0352     |
# |    std                  | 1.24        |
# |    value_loss           | 335         |
# -----------------------------------------
# Eval num_timesteps=86000, episode_reward=-467.93 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 106      |
# |    mean_reward     | -468     |
# | time/              |          |
# |    total_timesteps | 86000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -514     |
# | time/              |          |
# |    fps             | 2587     |
# |    iterations      | 42       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 86016    |
# ---------------------------------
# Eval num_timesteps=88000, episode_reward=-465.58 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -466        |
# | time/                   |             |
# |    total_timesteps      | 88000       |
# | train/                  |             |
# |    approx_kl            | 0.035341688 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.1       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 144         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0447     |
# |    std                  | 1.25        |
# |    value_loss           | 301         |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -514     |
# | time/              |          |
# |    fps             | 2586     |
# |    iterations      | 43       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 88064    |
# ---------------------------------
# Eval num_timesteps=90000, episode_reward=-462.27 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -462        |
# | time/                   |             |
# |    total_timesteps      | 90000       |
# | train/                  |             |
# |    approx_kl            | 0.030449314 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.1       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 85.8        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0369     |
# |    std                  | 1.25        |
# |    value_loss           | 244         |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -512     |
# | time/              |          |
# |    fps             | 2586     |
# |    iterations      | 44       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 90112    |
# ---------------------------------
# Eval num_timesteps=92000, episode_reward=-460.34 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 106        |
# |    mean_reward          | -460       |
# | time/                   |            |
# |    total_timesteps      | 92000      |
# | train/                  |            |
# |    approx_kl            | 0.03284385 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -13.2      |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 69.5       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.039     |
# |    std                  | 1.26       |
# |    value_loss           | 173        |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -509     |
# | time/              |          |
# |    fps             | 2585     |
# |    iterations      | 45       |
# |    time_elapsed    | 35       |
# |    total_timesteps | 92160    |
# ---------------------------------
# Eval num_timesteps=94000, episode_reward=-454.74 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -455        |
# | time/                   |             |
# |    total_timesteps      | 94000       |
# | train/                  |             |
# |    approx_kl            | 0.032412224 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.3       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.4        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0413     |
# |    std                  | 1.27        |
# |    value_loss           | 130         |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -508     |
# | time/              |          |
# |    fps             | 2582     |
# |    iterations      | 46       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 94208    |
# ---------------------------------
# Eval num_timesteps=96000, episode_reward=-449.33 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 106        |
# |    mean_reward          | -449       |
# | time/                   |            |
# |    total_timesteps      | 96000      |
# | train/                  |            |
# |    approx_kl            | 0.03877776 |
# |    clip_fraction        | 0.338      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -13.3      |
# |    explained_variance   | 0.989      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 20.3       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0425    |
# |    std                  | 1.28       |
# |    value_loss           | 85.5       |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -505     |
# | time/              |          |
# |    fps             | 2581     |
# |    iterations      | 47       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 96256    |
# ---------------------------------
# Eval num_timesteps=98000, episode_reward=-444.17 +/- 0.00
# Episode length: 106.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 106        |
# |    mean_reward          | -444       |
# | time/                   |            |
# |    total_timesteps      | 98000      |
# | train/                  |            |
# |    approx_kl            | 0.04043302 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -13.4      |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 22.5       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0405    |
# |    std                  | 1.29       |
# |    value_loss           | 51.3       |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -502     |
# | time/              |          |
# |    fps             | 2581     |
# |    iterations      | 48       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 98304    |
# ---------------------------------
# Eval num_timesteps=100000, episode_reward=-439.02 +/- 0.00
# Episode length: 106.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 106         |
# |    mean_reward          | -439        |
# | time/                   |             |
# |    total_timesteps      | 100000      |
# | train/                  |             |
# |    approx_kl            | 0.035846762 |
# |    clip_fraction        | 0.354       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.4       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0397     |
# |    std                  | 1.29        |
# |    value_loss           | 30.4        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -499     |
# | time/              |          |
# |    fps             | 2581     |
# |    iterations      | 49       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 100352   |
# ---------------------------------
# Training Complete.

# %% [markdown]
# The Smart Backtester (The Wrapper)
#
# The Engine that enforces the 5-10% threshold rule.

# %%
# Run Backtest on TEST Data
test_env = PortfolioRebalanceEnv(price_test, feat_test, bench_test)
# 1. Rerun Backtest with new logger
REBALANCE_THRESHOLD = 0.05
from rl_system import SmartBacktesterWithWeights
backtester = SmartBacktesterWithWeights(model, test_env, threshold=REBALANCE_THRESHOLD)
results = backtester.run()

# Visualization
plt.figure(figsize=(12, 6))
plt.plot(results['nav'], label='Smart AI Agent')

# Plot Trade Markers
trades = results[results['action'] == 'TRADE']
plt.scatter(trades.index, trades['nav'], color='red', marker='^', label='Rebalance')

plt.title("OOS Backtest: AI with 5% Threshold Wrapper")
plt.legend()
plt.show()

# Stats
start_val = results['nav'].iloc[0]
end_val = results['nav'].iloc[-1]
roi = (end_val / start_val) - 1
print(f"Total Return: {roi*100:.2f}%")
print(f"Trades Executed: {len(trades)}")
# Out:
# Total Return: 87.83%
# Trades Executed: 24

# %%
# 2. Process Weights Data
# Expand the 'weights' column (list of arrays) into a proper DataFrame
weight_cols = list(df_full.columns[:-1]) + ['Cash'] # Assets + Cash
weights_df = pd.DataFrame(results['weights'].tolist(), index=results.index, columns=weight_cols)

# 3. Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Use a Stacked Area Plot
weights_df.plot.area(ax=ax, cmap='tab20', alpha=0.9)

# Overlay the Rebalance Points (Red Triangles)
# We plot them at y=1.05 (just above the chart) to see WHEN it acted
rebalance_indices = results[results['action'] == 'TRADE'].index
ax.scatter(rebalance_indices, [1.02]*len(rebalance_indices), 
           color='red', marker='v', s=30, label='Rebalance Event', zorder=10)

plt.title("Portfolio Allocation Evolution (Stacked)")
plt.ylabel("Allocation %")
plt.xlabel("Time Steps")
plt.margins(0, 0) # Remove white space on sides
plt.ylim(0, 1.05) # Give space for the markers
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') # Move legend outside
plt.tight_layout()
plt.show()

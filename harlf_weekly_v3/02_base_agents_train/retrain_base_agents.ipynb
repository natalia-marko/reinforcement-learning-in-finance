# %% [markdown]
# ## Train Base Agents for Super Agent
#
# Trains 3 diverse base agents as ensembles.

# %%
import numpy as np
import json
from pathlib import Path
from train import train
from config import get_config

DATA_DIR = '../data_hierarchical'
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
# Simply run the training script functions
from utile_for_retrain_base_agents import train_all_base_agents

# Train all 3 agents with 5 models each
results = train_all_base_agents(n_seeds=10, save_path='../results/base_agents.json', verbose=True)
# Out:
# ...
# 🚀 TRAINING ALL BASE AGENTS FOR SUPER AGENT
# ...
# Number of base agents: 3
# Ensemble size per agent: 10
# Total models to train: 30
# Estimated time: 120-180 minutes
# ...
#
#
# ...
# 🎯 Training Base Agent: EMA_Sharpe_Technical_ReturnMax
# ...
# Agent Type:  technical
# Algorithm:   PPO
# Reward:      ema_sharpe
# Purpose:     Maximize returns - compromise params from best_choice
# Ensemble:    10 models
# ...
#
# 📋 Configuration Parameters:
#   gamma:                0.85
#   softmax_temperature:  1.0
#   learning_rate:        0.00026
#   total_steps:          500,000
#   patience:             15
#   transaction_cost:     0.001
#   rolling_vol_window:   12
#
#
# [1/10] Training with seed 42...
#   Train: 1.756 | Val: 2.293 | Test: 1.153
#
# [2/10] Training with seed 43...
#   Train: 2.010 | Val: 2.521 | Test: 1.322
#
# [3/10] Training with seed 44...
#   Train: 2.869 | Val: 2.631 | Test: 1.434
#
# [4/10] Training with seed 45...
#   Train: 2.724 | Val: 2.461 | Test: 1.438
#
# [5/10] Training with seed 46...
# ...
